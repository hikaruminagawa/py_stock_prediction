# %%
import datetime

import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

import pandas_datareader

import sklearn
import sklearn.linear_model
import sklearn.model_selection

import yfinance

yfinance.pdr_override()

# %%
df_aapl = pandas_datareader.data.get_data_yahoo('AAPL', '2020-01-01')
df_meta = pandas_datareader.data.get_data_yahoo('META', '2020-01-01')
df_gold = pandas_datareader.data.get_data_yahoo('GLD', '2020-01-01')
# Out:
# c:\Users\hminagawa\AppData\Local\Programs\Python\Python312\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# c:\Users\hminagawa\AppData\Local\Programs\Python\Python312\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# c:\Users\hminagawa\AppData\Local\Programs\Python\Python312\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed

# %%
df_aapl['SMA'] = df_aapl['Close'].rolling(window=14).mean()
df_aapl.tail(3)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-05-02  172.509995  173.419998  170.889999  173.029999  173.029999
# 2024-05-03  186.649994  187.000000  182.660004  183.380005  183.380005
# 2024-05-06  182.350006  184.199997  180.419998  181.710007  181.710007
#
#                Volume         SMA
# Date
# 2024-05-02   94214900  169.230000
# 2024-05-03  163224100  169.993572
# 2024-05-06   78057800  170.874286

# %%
#df_aapl['SMA']のDate列の最大値と最小値を'YYYY-MM-DD'のフォーマットで取得する
max_date = df_aapl['SMA'].index.max().strftime('%Y-%m-%d')
min_date = df_aapl['SMA'].index.min().strftime('%Y-%m-%d')

# %%
df_aapl['SMA'] = df_aapl['Close'].rolling(window=14).mean()
df_aapl['Close'].plot(figsize=(15, 6), color = 'red')
df_aapl['SMA'].plot(figsize=(15, 6), color = 'green')

#x軸を2020-01-02からにする
plt.xlim(min_date, max_date)

plt.legend()

plt.show()
